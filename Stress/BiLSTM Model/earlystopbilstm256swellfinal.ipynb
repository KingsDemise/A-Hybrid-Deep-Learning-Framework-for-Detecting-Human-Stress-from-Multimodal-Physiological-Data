# %%
import numpy as np
import pandas as pd 


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/hrv-dataset/hrv dataset/quick_start.py
# /kaggle/input/hrv-dataset/hrv dataset/papers/Koldijk et. al - 2018.pdf
# /kaggle/input/hrv-dataset/hrv dataset/papers/Kizito et. al - 2019.pdf
# /kaggle/input/hrv-dataset/hrv dataset/papers/Koldijk et al. - 2014pdf.pdf
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/quick_start.py
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/papers/Koldijk et. al - 2018.pdf
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/papers/Kizito et. al - 2019.pdf
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/papers/Koldijk et al. - 2014pdf.pdf
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p17.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p7.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p12.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p19.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p15.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p16.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p13.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p10.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p6.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p9.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p21.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p24.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p18.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p22.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p14.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p4.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p5.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p1.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p25.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p2.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p3.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p20.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/rri/p23.txt
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/raw/labels/hrv stress labels.xlsx
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/final/train.csv
# /kaggle/input/hrv-dataset/hrv dataset/hrv dataset/data/final/test.csv
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p17.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p7.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p12.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p19.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p15.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p16.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p13.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p10.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p6.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p9.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p21.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p24.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p18.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p22.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p14.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p4.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p5.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p1.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p25.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p2.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p3.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p20.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/rri/p23.txt
# /kaggle/input/hrv-dataset/hrv dataset/data/raw/labels/hrv stress labels.xlsx
# /kaggle/input/hrv-dataset/hrv dataset/data/final/train.csv
# /kaggle/input/hrv-dataset/hrv dataset/data/final/test.csv

# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, LSTM, Dense, Dropout, Flatten
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
# %load_ext tensorboard
# Out:
# 2024-01-30 15:45:16.750654: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-30 15:45:16.750771: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-30 15:45:16.880618: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Data Preprocessing

# %%
df_test = pd.read_csv(r"../input/hrv-dataset/hrv dataset/data/final/test.csv")
df_train = pd.read_csv(r"../input/hrv-dataset/hrv dataset/data/final/train.csv")
print(f"df_train shape{df_train.shape}")
print(f"df_test shape{df_test.shape}")
# Out:
# df_train shape(369289, 36)
# df_test shape(41033, 36)

# %%
df_train.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  885.157845  853.763730  140.972741  15.554505  15.553371    9.063146
# 1  939.425371  948.357865   81.317742  12.964439  12.964195    6.272369
# 2  898.186047  907.006860   84.497236  16.305279  16.305274    5.182201
# 3  881.757865  893.460030   90.370537  15.720468  15.720068    5.748591
# 4  809.625331  811.184865   62.766242  19.213819  19.213657    3.266724
#
#           HR      pNN25     pNN50        SD1  ...         HF    HF_PCT  \
# 0  69.499952  11.133333  0.533333  11.001565  ...  15.522603  0.421047
# 1  64.363150   5.600000  0.000000   9.170129  ...   2.108525  0.070133
# 2  67.450066  13.066667  0.200000  11.533417  ...  13.769729  0.512671
# 3  68.809562  11.800000  0.133333  11.119476  ...  18.181913  0.529387
# 4  74.565728  20.200000  0.200000  13.590641  ...  48.215822  1.839473
#
#       HF_NU           TP       LF_HF     HF_LF    sampen    higuci  datasetId  \
# 0  1.514737  3686.666157   65.018055  0.015380  2.139754  1.163485          2
# 1  0.304603  3006.487251  327.296635  0.003055  2.174499  1.084711          2
# 2  1.049528  2685.879461   94.280910  0.010607  2.135350  1.176315          2
# 3  1.775294  3434.520980   55.328701  0.018074  2.178341  1.179688          2
# 4  3.279993  2621.175204   29.487873  0.033912  2.221121  1.249612          2
#
#       condition
# 0     no stress
# 1  interruption
# 2  interruption
# 3     no stress
# 4     no stress
#
# [5 rows x 36 columns]

# %%
df_train['condition'].unique()
# Out:
# array(['no stress', 'interruption', 'time pressure'], dtype=object)

# %%
display(df_train.info())
display(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369289 entries, 0 to 369288
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   MEAN_RR            369289 non-null  float64
#  1   MEDIAN_RR          369289 non-null  float64
#  2   SDRR               369289 non-null  float64
#  3   RMSSD              369289 non-null  float64
#  4   SDSD               369289 non-null  float64
#  5   SDRR_RMSSD         369289 non-null  float64
#  6   HR                 369289 non-null  float64
#  7   pNN25              369289 non-null  float64
#  8   pNN50              369289 non-null  float64
#  9   SD1                369289 non-null  float64
#  10  SD2                369289 non-null  float64
#  11  KURT               369289 non-null  float64
#  12  SKEW               369289 non-null  float64
#  13  MEAN_REL_RR        369289 non-null  float64
#  14  MEDIAN_REL_RR      369289 non-null  float64
#  15  SDRR_REL_RR        369289 non-null  float64
#  16  RMSSD_REL_RR       369289 non-null  float64
#  17  SDSD_REL_RR        369289 non-null  float64
#  18  SDRR_RMSSD_REL_RR  369289 non-null  float64
#  19  KURT_REL_RR        369289 non-null  float64
#  20  SKEW_REL_RR        369289 non-null  float64
#  21  VLF                369289 non-null  float64
#  22  VLF_PCT            369289 non-null  float64
#  23  LF                 369289 non-null  float64
#  24  LF_PCT             369289 non-null  float64
#  25  LF_NU              369289 non-null  float64
#  26  HF                 369289 non-null  float64
#  27  HF_PCT             369289 non-null  float64
#  28  HF_NU              369289 non-null  float64
#  29  TP                 369289 non-null  float64
#  30  LF_HF              369289 non-null  float64
#  31  HF_LF              369289 non-null  float64
#  32  sampen             369289 non-null  float64
#  33  higuci             369289 non-null  float64
#  34  datasetId          369289 non-null  int64
#  35  condition          369289 non-null  object
# dtypes: float64(34), int64(1), object(1)
# memory usage: 101.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41033 entries, 0 to 41032
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MEAN_RR            41033 non-null  float64
#  1   MEDIAN_RR          41033 non-null  float64
#  2   SDRR               41033 non-null  float64
#  3   RMSSD              41033 non-null  float64
#  4   SDSD               41033 non-null  float64
#  5   SDRR_RMSSD         41033 non-null  float64
#  6   HR                 41033 non-null  float64
#  7   pNN25              41033 non-null  float64
#  8   pNN50              41033 non-null  float64
#  9   SD1                41033 non-null  float64
#  10  SD2                41033 non-null  float64
#  11  KURT               41033 non-null  float64
#  12  SKEW               41033 non-null  float64
#  13  MEAN_REL_RR        41033 non-null  float64
#  14  MEDIAN_REL_RR      41033 non-null  float64
#  15  SDRR_REL_RR        41033 non-null  float64
#  16  RMSSD_REL_RR       41033 non-null  float64
#  17  SDSD_REL_RR        41033 non-null  float64
#  18  SDRR_RMSSD_REL_RR  41033 non-null  float64
#  19  KURT_REL_RR        41033 non-null  float64
#  20  SKEW_REL_RR        41033 non-null  float64
#  21  VLF                41033 non-null  float64
#  22  VLF_PCT            41033 non-null  float64
#  23  LF                 41033 non-null  float64
#  24  LF_PCT             41033 non-null  float64
#  25  LF_NU              41033 non-null  float64
#  26  HF                 41033 non-null  float64
#  27  HF_PCT             41033 non-null  float64
#  28  HF_NU              41033 non-null  float64
#  29  TP                 41033 non-null  float64
#  30  LF_HF              41033 non-null  float64
#  31  HF_LF              41033 non-null  float64
#  32  sampen             41033 non-null  float64
#  33  higuci             41033 non-null  float64
#  34  datasetId          41033 non-null  int64
#  35  condition          41033 non-null  object
# dtypes: float64(34), int64(1), object(1)
# memory usage: 11.3+ MB
# None

# %%
df_train['condition'] = df_train['condition'].map({'no stress':0, 'interruption':1, 'time pressure':2})
df_test['condition'] = df_test['condition'].map({'no stress':0, 'interruption':1, 'time pressure':2})

# %%
df_train.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  885.157845  853.763730  140.972741  15.554505  15.553371    9.063146
# 1  939.425371  948.357865   81.317742  12.964439  12.964195    6.272369
# 2  898.186047  907.006860   84.497236  16.305279  16.305274    5.182201
# 3  881.757865  893.460030   90.370537  15.720468  15.720068    5.748591
# 4  809.625331  811.184865   62.766242  19.213819  19.213657    3.266724
#
#           HR      pNN25     pNN50        SD1  ...         HF    HF_PCT  \
# 0  69.499952  11.133333  0.533333  11.001565  ...  15.522603  0.421047
# 1  64.363150   5.600000  0.000000   9.170129  ...   2.108525  0.070133
# 2  67.450066  13.066667  0.200000  11.533417  ...  13.769729  0.512671
# 3  68.809562  11.800000  0.133333  11.119476  ...  18.181913  0.529387
# 4  74.565728  20.200000  0.200000  13.590641  ...  48.215822  1.839473
#
#       HF_NU           TP       LF_HF     HF_LF    sampen    higuci  datasetId  \
# 0  1.514737  3686.666157   65.018055  0.015380  2.139754  1.163485          2
# 1  0.304603  3006.487251  327.296635  0.003055  2.174499  1.084711          2
# 2  1.049528  2685.879461   94.280910  0.010607  2.135350  1.176315          2
# 3  1.775294  3434.520980   55.328701  0.018074  2.178341  1.179688          2
# 4  3.279993  2621.175204   29.487873  0.033912  2.221121  1.249612          2
#
#    condition
# 0          0
# 1          1
# 2          1
# 3          0
# 4          0
#
# [5 rows x 36 columns]

# %%
X = df_train.iloc[:, :-1].values
y = df_train.iloc[:, -1].values

# %% [markdown]
# # Model Creation and Training

# %%
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Conv1D, MaxPooling1D, Dropout, Dense
from sklearn.model_selection import train_test_split


X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

model = Sequential()


model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same', input_shape=(X.shape[1], 1)))
model.add(MaxPooling1D(pool_size=1))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(pool_size=1))

model.add(Bidirectional(LSTM(256, return_sequences=False)))
model.add(Dropout(0.4))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))  
model.add(Dense(3, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=128)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706629540.877789     105 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2020/2020 [==============================] - 38s 15ms/step - loss: 0.6090 - accuracy: 0.7307 - val_loss: 0.3015 - val_accuracy: 0.8759
# Epoch 2/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.2030 - accuracy: 0.9207 - val_loss: 0.0873 - val_accuracy: 0.9693
# Epoch 3/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0860 - accuracy: 0.9698 - val_loss: 0.0505 - val_accuracy: 0.9819
# Epoch 4/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0555 - accuracy: 0.9817 - val_loss: 0.0514 - val_accuracy: 0.9815
# Epoch 5/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0450 - accuracy: 0.9856 - val_loss: 0.0095 - val_accuracy: 0.9971
# Epoch 6/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0370 - accuracy: 0.9886 - val_loss: 0.0159 - val_accuracy: 0.9948
# Epoch 7/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.0182 - val_accuracy: 0.9947
# Epoch 8/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0274 - accuracy: 0.9917 - val_loss: 0.0103 - val_accuracy: 0.9965
# Epoch 9/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.0134 - val_accuracy: 0.9956
# Epoch 10/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0256 - accuracy: 0.9923 - val_loss: 0.0042 - val_accuracy: 0.9986
# Epoch 11/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0232 - accuracy: 0.9931 - val_loss: 0.0175 - val_accuracy: 0.9953
# Epoch 12/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0246 - accuracy: 0.9928 - val_loss: 0.0049 - val_accuracy: 0.9986
# Epoch 13/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 0.0125 - val_accuracy: 0.9965
# Epoch 14/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0192 - accuracy: 0.9943 - val_loss: 0.0055 - val_accuracy: 0.9981
# Epoch 15/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0191 - accuracy: 0.9943 - val_loss: 0.0084 - val_accuracy: 0.9969
# Epoch 16/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.0069 - val_accuracy: 0.9979
# Epoch 17/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0180 - accuracy: 0.9949 - val_loss: 0.0071 - val_accuracy: 0.9984
# Epoch 18/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.0025 - val_accuracy: 0.9992
# Epoch 19/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0154 - accuracy: 0.9956 - val_loss: 0.0089 - val_accuracy: 0.9969
# Epoch 20/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.0036 - val_accuracy: 0.9989
# Epoch 21/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0151 - accuracy: 0.9958 - val_loss: 0.0219 - val_accuracy: 0.9947
# Epoch 22/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0136 - accuracy: 0.9964 - val_loss: 0.0129 - val_accuracy: 0.9963
# Epoch 23/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0120 - val_accuracy: 0.9966
# Epoch 24/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.0314 - val_accuracy: 0.9923
# Epoch 25/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0146 - accuracy: 0.9960 - val_loss: 0.0061 - val_accuracy: 0.9980
# Epoch 26/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.0059 - val_accuracy: 0.9982
# Epoch 27/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.0068 - val_accuracy: 0.9978
# Epoch 28/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0113 - accuracy: 0.9969 - val_loss: 0.0050 - val_accuracy: 0.9985
# Epoch 29/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 0.0041 - val_accuracy: 0.9985
# Epoch 30/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 0.0020 - val_accuracy: 0.9993
# Epoch 31/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.0040 - val_accuracy: 0.9988
# Epoch 32/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 0.0287 - val_accuracy: 0.9924
# Epoch 33/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0105 - accuracy: 0.9972 - val_loss: 0.0041 - val_accuracy: 0.9988
# Epoch 34/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0118 - accuracy: 0.9967 - val_loss: 0.0024 - val_accuracy: 0.9992
# Epoch 35/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.0137 - val_accuracy: 0.9965
# Epoch 36/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.0105 - val_accuracy: 0.9968
# Epoch 37/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.0106 - val_accuracy: 0.9963
# Epoch 38/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0088 - accuracy: 0.9977 - val_loss: 0.0027 - val_accuracy: 0.9991
# Epoch 39/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.0301 - val_accuracy: 0.9925
# Epoch 40/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.0045 - val_accuracy: 0.9988
# Epoch 41/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0103 - accuracy: 0.9974 - val_loss: 0.0034 - val_accuracy: 0.9989
# Epoch 42/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.0051 - val_accuracy: 0.9981
# Epoch 43/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 9.8533e-04 - val_accuracy: 0.9998
# Epoch 44/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0088 - accuracy: 0.9977 - val_loss: 0.0123 - val_accuracy: 0.9970
# Epoch 45/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.0164 - val_accuracy: 0.9953
# Epoch 46/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0028 - val_accuracy: 0.9991
# Epoch 47/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 0.0035 - val_accuracy: 0.9991
# Epoch 48/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.0033 - val_accuracy: 0.9991
# Epoch 49/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0038 - val_accuracy: 0.9990
# Epoch 50/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0030 - val_accuracy: 0.9992
# Epoch 51/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0094 - val_accuracy: 0.9973
# Epoch 52/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.0021 - val_accuracy: 0.9994
# Epoch 53/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 0.0023 - val_accuracy: 0.9993
# Epoch 54/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 6.7781e-04 - val_accuracy: 0.9998
# Epoch 55/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.0095 - val_accuracy: 0.9975
# Epoch 56/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 9.0990e-04 - val_accuracy: 0.9997
# Epoch 57/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.0025 - val_accuracy: 0.9994
# Epoch 58/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.0171 - val_accuracy: 0.9950
# Epoch 59/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.0053 - val_accuracy: 0.9983
# Epoch 60/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0146 - val_accuracy: 0.9963
# Epoch 61/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9966
# Epoch 62/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 0.0027 - val_accuracy: 0.9994
# Epoch 63/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.0042 - val_accuracy: 0.9989
# Epoch 64/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0014 - val_accuracy: 0.9995
# Epoch 65/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 6.0796e-04 - val_accuracy: 0.9998
# Epoch 66/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.0028 - val_accuracy: 0.9995
# Epoch 67/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0041 - val_accuracy: 0.9989
# Epoch 68/100
# 2020/2020 [==============================] - 29s 14ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.0032 - val_accuracy: 0.9991
# Epoch 69/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.0258 - val_accuracy: 0.9925
# Epoch 70/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0027 - val_accuracy: 0.9990
# Epoch 71/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0073 - val_accuracy: 0.9979
# Epoch 72/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0076 - accuracy: 0.9981 - val_loss: 0.0094 - val_accuracy: 0.9968
# Epoch 73/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0028 - val_accuracy: 0.9993
# Epoch 74/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.0031 - val_accuracy: 0.9988
# Epoch 75/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.0013 - val_accuracy: 0.9995
# Epoch 76/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.0014 - val_accuracy: 0.9993
# Epoch 77/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0069 - accuracy: 0.9982 - val_loss: 0.0056 - val_accuracy: 0.9982
# Epoch 78/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0069 - accuracy: 0.9982 - val_loss: 0.0011 - val_accuracy: 0.9997
# Epoch 79/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.0022 - val_accuracy: 0.9994
# Epoch 80/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0044 - val_accuracy: 0.9989
# Epoch 81/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0078 - val_accuracy: 0.9985
# Epoch 82/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0044 - val_accuracy: 0.9988
# Epoch 83/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0014 - val_accuracy: 0.9995
# Epoch 84/100
# 2020/2020 [==============================] - 29s 15ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.0028 - val_accuracy: 0.9991
# Epoch 85/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0223 - val_accuracy: 0.9958
# Epoch 86/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.0159 - val_accuracy: 0.9942
# Epoch 87/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 9.9298e-04 - val_accuracy: 0.9997
# Epoch 88/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 5.1920e-04 - val_accuracy: 0.9999
# Epoch 89/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0023 - val_accuracy: 0.9992
# Epoch 90/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.0113 - val_accuracy: 0.9973
# Epoch 91/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.0053 - val_accuracy: 0.9984
# Epoch 92/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0013 - val_accuracy: 0.9996
# Epoch 93/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.0087 - val_accuracy: 0.9981
# Epoch 94/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0077 - accuracy: 0.9981 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 95/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0064 - val_accuracy: 0.9985
# Epoch 96/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0075 - val_accuracy: 0.9975
# Epoch 97/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 5.0958e-04 - val_accuracy: 0.9998
# Epoch 98/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.0050 - val_accuracy: 0.9983
# Epoch 99/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.0046 - val_accuracy: 0.9986
# Epoch 100/100
# 2020/2020 [==============================] - 30s 15ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 3.3683e-04 - val_accuracy: 0.9999

# %% [markdown]
# # Evaluation

# %%
X_test = df_test.iloc[:, :-1].values
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1) 
y_test = df_test.iloc[:, -1].values
test_loss, test_acc = model.evaluate(X_test, y_test)

print(f"Test accuracy: {test_acc}")
print(f"Test loss: {test_loss}")

validation_accuracy = history.history['val_accuracy'][99]
validation_loss = history.history['val_loss'][99]

print("Validation Accuracy:", validation_accuracy)
print("Validation Loss:", validation_loss)
# Out:
# 1283/1283 [==============================] - 6s 4ms/step - loss: 6.0773e-04 - accuracy: 0.9998
# Test accuracy: 0.9997806549072266
# Test loss: 0.0006077310536056757
# Validation Accuracy: 0.9998826384544373
# Validation Loss: 0.00033683489891700447

# %%
from sklearn.metrics import classification_report
predict_x=model.predict(X_test)
y_pred=np.argmax(predict_x,axis=1)
print(f"Classification Report: \n{classification_report(y_test, y_pred)}")
# Out:
# 1283/1283 [==============================] - 5s 3ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     22158
#            1       1.00      1.00      1.00     11782
#            2       1.00      1.00      1.00      7093
#
#     accuracy                           1.00     41033
#    macro avg       1.00      1.00      1.00     41033
# weighted avg       1.00      1.00      1.00     41033

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 35, 128)           512
#
#  max_pooling1d (MaxPooling1  (None, 35, 128)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 35, 64)            24640
#
#  max_pooling1d_1 (MaxPoolin  (None, 35, 64)            0
#  g1D)
#
#  bidirectional (Bidirection  (None, 512)               657408
#  al)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 814659 (3.11 MB)
# Trainable params: 814659 (3.11 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Confusion Matrix

# %%
def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()


y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
plot_confusion_matrix(y_test, y_pred, classes=['no stress', 'interruption', 'time pressure'])
# Out:
# 1283/1283 [==============================] - 4s 3ms/step

# %% [markdown]
# # Training & Validation Curves

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Receiver Operating Characteristic (ROC) curve and Area Under Curve (AUC)

# %%
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])
y_pred_proba = model.predict(X_test)


fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


plt.figure(figsize=(10, 8))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 1283/1283 [==============================] - 4s 3ms/step
